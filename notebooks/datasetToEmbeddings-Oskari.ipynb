# %%
from InstructorEmbedding import INSTRUCTOR

import os
import pandas as pd
import pathlib
import chromadb
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from matplotlib import pyplot as plt

os.environ["OPENAI_API_KEY"] = ""

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../src/data/'))
from s3_utils import read_from_s3, write_to_s3
from chromadb.config import Settings
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
def preprocess_transcripts(transcripts_df):
    """ 
    Function that does preprocessing steps:
    - Split transcripts into chunks of 20000 characters
    - Explode to new rows
    - Remove transcripts with less than 1000 characters
    """
    transcripts_df['transcript'] = transcripts_df['transcript'].apply(lambda x: [x[i:i+20000] for i in range(0, len(x), 20000)])
    transcripts_df = transcripts_df.explode('transcript')
    transcripts_df['transcript_length'] = transcripts_df['transcript'].apply(lambda x: len(x))
    transcripts_df = transcripts_df[transcripts_df['transcript_length'] > 1000].reset_index(drop=True)
    return transcripts_df

# %%
# prepare texts with instructions
instruction = "Represent the Podcast transcript for retrieval: "

# read transcript data
filename = 'podcasts-transcripts-0to2-35.csv'

transcripts_df = read_from_s3(filename, filetype=None)
# transcripts_df = preprocess_transcripts(transcripts_df)
transcripts_df = transcripts_df.head(100)

# Create list of instruction - transcript pairs (100 first episodes)
# transcripts_df  = transcripts_df.head(100)
texts_with_instructions = []
for index, row in transcripts_df.iterrows():
    texts_with_instructions.append([instruction, row["transcript"]])

# calculate embeddings (100 first episodes took about 6 min)
# model = INSTRUCTOR('hkunlp/instructor-large')
# customized_embeddings = model.encode(texts_with_instructions, show_progress_bar=True, batch_size=16)
texts_with_instructions[0]
# Out:
# ['Represent the Podcast transcript for retrieval: ',
#  "Hi everyone, and welcome to murder friends the podcast were three friends from three different countries talk about murder. My name is Alana and I'm Canadian. Hi, I'm Anna and I'm American. My name is Hannah and I'm British. So sit back and relax you're among friends. And let's talk murder. Now. Today's episode is really special because it is the conclusion of spooky month. Which in my opinion is probably the best month. You're right. I love Halloween is the best time of year. For the whole month, really? Yes spooky season. It's pretty great. I mean in general you could start wearing sweaters boots, you know, go completely black and goth and coffee. Yeah spice lattes if that's your sort of basic thing, you know, which is because it is and if you're a more murdery, no than its quad gourd season. Yeah, exactly. The only thing that I've noticed so I've been living in England for just a couple of years. And England doesn't do Halloween like North America does which is kind of a bummer, but I guess I just sort of get used to it. Where is like in Canada? It feels like everything is draped in fake cobwebs from like October 5th and on like the stores go all out all the houses go all out costumes go all out. We're here in England. Not that so much of a popular thing. Now, it's I noticed that too because I'm America as well. It's insane. Like people go nuts for Halloween. It's a big thing. I mean nobody costume people decorate their whole house. I mean some go even more nuts than Christmas with the whole house decorating. I mean, it's a massive massive thing and every house participates like here you might get obviously I have a little one so I have been trick-or-treating here with her and you might get like two houses on the street. It's just it's pretty pathetic but  But it's only because you guys don't do it. Yeah, I was never really like a thing when I was a kid. I mean it really bad Halloween, but we never went trick-or-treating we didn't do like costumes that much there were like the occasional Halloween party. But like that was a yeah, but I think that's mainly because we don't a bigger event in the UK is probably Guy Fawkes Night. Yeah, and it's so full of November. Yes, I bonfire night which is I think more of our like traditionally  British thing today. Yes, you do firework doesn't everything you don't think we set things on fire. So we do that more in Fourth of July. Yeah. I just remember like growing up in Canada Halloween you get your costume ready? Like two months in advance. So shout out to know you're like you're literally talking about it. Aren't you like for with your friends? Oh, yeah who can come up with the best costume? Yes, and then you all go to Value Village. Shout out to Value Village anybody who lived loves Value Village they are  Like a charity shop, but they go full out on Halloween because everybody goes there to buy their costume. So like you by bits and pieces and whatever so you go to Value Village. I remember one year. I must have been I want to say like nine and I was a mad scientist for Halloween true story. I'll have to dig up a picture and my mom was so good at costumes. We got this white lab coat and then ping pong balls. We like glued all over and Drew like little eyeballs on them.  And then I got like a one of the you know, like the dollar store has like a packet of plastic bugs so glued plastic bags all over I had a giant like plastic rat that we like so to my shoulder and then my mom in her absolute Grace and wisdom because it is a Halloween in Canada and it's fucking cold. She built this hat. Basically that was pink sort of like Shivani material that she  She sewed and wrapped up and put it onto a hat. So it looked like an exposed. Brain. Oh my God. Yeah, I'm not kidding and buy things like oh, so it's like a it looks really fucking cool. You're a mad scientist with an exposed brain and be your warm as hell because it's an actual hat and it's Halloween in Canada. So it might be snowing. I ju ...

# %%
# from transformers import GPT2TokenizerFast
import transformers
from langchain.text_splitter import CharacterTextSplitter
from langchain.text_splitter import TokenTextSplitter

#tokenizer = transformers.AutoTokenizer.from_pretrained('hkunlp/instructor-large')
#tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")
filename = 'podcasts-transcripts-0to2-13.csv'

transcripts_df = read_from_s3(filename, filetype=None)
transcript = texts_with_instructions[0][1]
#text_splitter = CharacterTextSplitter.from_huggingface_tokenizer(tokenizer, chunk_size=512, chunk_overlap=0)
text_splitter = TokenTextSplitter(chunk_size=2500, chunk_overlap=0)
transcripts_df["transcript_length"] = transcripts_df["transcript"].apply(lambda x: len(x))
transcripts_df = transcripts_df[transcripts_df["transcript_length"] > 1000]
transcripts_df.loc[:,"transcript"] = transcripts_df["transcript"].apply(lambda x: text_splitter.split_text(x))
#transcripts_df['num_of_splits'] = transcripts_df['splitted_text'].apply(lambda x: len(x))

#transcripts_df['num_of_splits'].describe()
transcripts_df.reset_index(drop=True).head(3)
# Out:
#                                           transcript  \
# 0  [Just wanted to take a brief moment to give yo...
# 1  [Just wanted to take a brief moment to give yo...
# 2  [Just wanted to take a brief moment to give yo...
#
#                           show                 episode  \
# 0  show_02Yjg2GfjecTzu0NbTV1HD  5EvN3tk0Y8gEWWRUzFRsfh
# 1  show_02Yjg2GfjecTzu0NbTV1HD  6SKHSUqdHKe3wQuxovgCmm
# 2  show_02Yjg2GfjecTzu0NbTV1HD  6HiVnhPXYlpR5Gu56XH8Qg
#
#                               show_uri      show_name  \
# 0  spotify:show:02Yjg2GfjecTzu0NbTV1HD  Paddle N' Fin
# 1  spotify:show:02Yjg2GfjecTzu0NbTV1HD  Paddle N' Fin
# 2  spotify:show:02Yjg2GfjecTzu0NbTV1HD  Paddle N' Fin
#
#                                     show_description             publisher  \
# 0  Paddle N' Fin is your goto for Fishing, Kayak,...  Paddle N Fin Network
# 1  Paddle N' Fin is your goto for Fishing, Kayak,...  Paddle N Fin Network
# 2  Paddle N' Fin is your goto for Fishing, Kayak,...  Paddle N Fin Network
#
#     language                                 rss_link  \
# 0  ['en-US']  https://anchor.fm/s/44ec0b0/podcast/rss
# 1  ['en-US']  https://anchor.fm/s/44ec0b0/podcast/rss
# 2  ['en-US']  https://anchor.fm/s/44ec0b0/podcast/rss
#
#                               episode_uri  \
# 0  spotify:episode:5EvN3tk0Y8gEWWRUzFRsfh
# 1  spotify:episode:6SKHSUqdHKe3wQuxovgCmm
# 2  spotify:episode:6HiVnhPXYlpR5Gu56XH8Qg
#
#                                         episode_name  \
# 0         S3E22. Reel Down with Nauti Fish from TKAA
# 1  S1E44.  New Prop, Giant Smallmouth, Wisconsin ...
# 2                        S1E34. Tennessee Trip Recap
#
#                                  episode_description   duration  \
# 0  Your Host Sam Jones and the OG Brian Schiller ...  56.017367
# 1  Brian and Jay sit down and chat about this pas...  50.465483
# 2  Brian and Jay sit down to chat about this past...  54.146233
#
#           show_filename_prefix episode_filename_prefix  \
# 0  show_02Yjg2GfjecTzu0NbTV1HD  5EvN3tk0Y8gEWWRUzFRsfh
# 1  show_02Yjg2GfjecTzu0NbTV1HD  6SKHSUqdHKe3wQuxovgCmm
# 2  show_02Yjg2GfjecTzu0NbTV1HD  6HiVnhPXYlpR5Gu56XH8Qg
#
#                         source_file  transcript_length
# 0  podcasts-transcripts-0to2.tar.gz              45764
# 1  podcasts-transcripts-0to2.tar.gz              36529
# 2  podcasts-transcripts-0to2.tar.gz              42174

# %%
from InstructorEmbedding import INSTRUCTOR
model = INSTRUCTOR('hkunlp/instructor-large')
model.max_seq_length = 512
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
text_splitter = TokenTextSplitter(chunk_size=4096, chunk_overlap=0)
texts = text_splitter.split_text(transcript)
instruction = "Represent the Podcast transcript for retrieval: "
texts_with_instructions = []
for i in range(1):
    text = texts[i]
    texts_with_instructions.append([instruction, text])
customized_embeddings = model.encode(texts_with_instructions, show_progress_bar=True, batch_size=32)
customized_embeddings
# Out:
# Batches: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# array([[-5.16323410e-02,  6.67927694e-03, -8.85380805e-03,
#          2.44533196e-02,  4.25812751e-02,  1.54207665e-02,
#         -1.50699094e-02,  3.12019289e-02, -5.03524877e-02,
#          6.62412420e-02,  4.46674079e-02, -3.49719706e-03,
#          3.33244726e-02,  2.95191091e-02, -2.37314161e-02,
#         -3.90568678e-03, -2.18310207e-02,  2.83075590e-02,
#         -3.82242575e-02,  5.62727312e-03,  4.54290770e-02,
#          3.08722332e-02,  2.85880733e-02,  3.92169580e-02,
#          4.76138666e-02,  3.13129425e-02, -2.64866650e-02,
#          3.40732262e-02,  4.13482450e-02, -7.31522217e-02,
#          4.99199815e-02, -3.32918204e-02, -3.03022228e-02,
#         -5.33378944e-02, -2.74871886e-02, -3.54510266e-03,
#          2.04877574e-02,  3.19864415e-02,  2.18761712e-02,
#          6.83443621e-02, -1.20599801e-02, -2.10893080e-02,
#         -3.27954954e-03, -4.55695502e-02,  1.09888113e-03,
#          7.08918273e-03, -6.10362217e-02, -2.55248547e-02,
#          3.25700752e-02, -4.28426787e-02,  6.27499679e-03,
#          2.27220487e-02, -4.60102297e-02, -9.92161706e-02,
#         -9.02064890e-03,  3.90270017e-02,  8.77444353e-03,
#         -1.53522298e-03, -2.71596517e-02,  1.18214674e-02,
#          7.27715483e-03,  1.99066643e-02, -2.00761724e-02,
#          3.07141105e-03,  6.23661513e-03, -1.99977178e-02,
#         -5.74975759e-02,  5.82800098e-02,  7.95654953e-03,
#         -1.39794983e-02, -1.10598570e-02, -2.19712667e-02,
#          1.22914100e-02,  7.77971419e-03, -3.77579243e-03,
#          7.88585003e-03, -7.69926161e-02, -6.76163333e-03,
#          1.21716112e-02,  2.62833145e-02,  3.99253480e-02,
#         -7.12703029e-03,  3.38645689e-02,  4.03855294e-02,
#          2.80128457e-02, -7.19216317e-02,  7.77362334e-03,
#         -6.62691668e-02,  3.05836499e-02, -9.16708857e-02,
#          8.55947193e-03, -1.77776236e-02, -6.94254339e-02,
#         -4.75612730e-02,  9.28693730e-03, -7.08684325e-03,
#         -6.81529474e-03, -6.64826110e-02,  2.43033767e-02,
#          6.34333044e-02,  1.87976919e-02, -1.65742785e-02,
#         -2.95502339e-02, -4.97649983e-02, -3.46082039e-02,
#          5.61579922e-03,  3.29825245e-02, -4.41997200e-02,
#         -6.92817429e-03, -5.22400513e-02,  1.01841567e-02,
#          3.34693938e-02,  1.30518079e-02, -2.88533904e-02,
#          6.21530861e-02,  4.39477861e-02, -3.40555981e-02,
#          9.25016531e-04,  1.30759533e-02, -3.59942950e-02,
#          3.40886302e-02,  4.15152945e-02,  1.49024902e-02,
#          8.68632738e-03,  3.52689065e-02, -3.00041791e-02,
#         -1.04691961e-03, -3.13865654e-02, -5.70032746e-02,
#         -2.88479906e-02,  2.36238297e-02,  4.47853506e-02]], dtype=float32)

# %%
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
persist_directory = 'test-db'

# format data that if can be put to the chroma collection
embeddings = customized_embeddings.tolist()
documents = transcripts_df["transcript"].tolist()
ids = transcripts_df.index.astype(str).to_list()
metadata = transcripts_df[['episode_description', 'episode_name']].to_dict(orient='records')

#loading into chroma
#client = chromadb.PersistentClient(path=persist_directory)
model = INSTRUCTOR('hkunlp/instructor-large')
server_ip = os.getenv('CHROMA_SERVER_IP')
client = chromadb.HttpClient(host=server_ip, port=8000)
collection = client.get_collection(name="transcripts", embedding_function=model)


# create the collection and add documents
try:
    client.delete_collection("transcripts")
except Exception as e:
    pass
collection = client.create_collection("transcripts", embedding_function=model)
collection.add(
    embeddings=embeddings,
    documents=documents,
    metadatas=metadata,
    ids=ids,
)

# %%
import boto3
import pandas as pd
my_session = boto3.Session(region_name='eu-central-1', profile_name='my-admin-profile')
client = boto3.client('s3')
files = client.list_objects(Bucket='sumar-ai')['Contents']
filenames = [f['Key'] for f in files][1:4]
processed_files_df = pd.DataFrame({"processed_files" : filenames})
processed_files_df
#processed_files_df.loc[processed_files_df.index.max() + 1] = "test"
#processed_files_df
write_to_s3(processed_files_df, 'processed_files', 'metadata')

# %%
processed_files_df = read_from_s3('processed_files', 'metadata')
processed_files_list = list(processed_files_df.processed_files)
processed_files_df.loc[processed_files_df.index.max() + 1] = "test"
processed_files_df
# Out:
# ---------------------------------------------------------------------------
# TokenRetrievalError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 processed_files_df = read_from_s3('processed_files', 'metadata')
#       2 processed_files_list = list(processed_files_df.processed_files)
#       3 processed_files_df.loc[processed_files_df.index.max() + 1] = "test"
#
# File ~/Library/CloudStorage/OneDrive-finnair365/data-science-studies/SumarAI/src/data/s3_utils.py:23, in read_from_s3(filename, filetype)
#      20 path1 = f"s3://{bucket}/{filetype}/{filename}"
#      22 # df = wr.s3.read_csv(path=path1, boto3_session=my_session)
# ---> 23 df = wr.s3.read_csv(path=path1)
#      24 return df
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/_utils.py:176, in validate_kwargs.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     173 if condition_fn() and len(passed_unsupported_kwargs) > 0:
#     174     raise exceptions.InvalidArgument(f"{message} `{', '.join(passed_unsupported_kwargs)}`.")
# --> 176 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/s3/_read_text.py:293, in read_csv(path, path_suffix, path_ignore_suffix, version_id, ignore_empty, use_threads, last_modified_begin, last_modified_end, boto3_session, s3_additional_kwargs, dtype_backend, chunksize, dataset, partition_filter, ray_args, **pandas_kwargs)
#     291 s3_client = _utils.client(service_name="s3", session=boto3_session)
#     292 ignore_index: bool = "index_col" not in pandas_kwargs
# --> 293 return _read_text_format(
#     294     read_format="csv",
#     295     path=path,
#     296     path_suffix=path_suffix,
#     297     path_ignore_suffix=path_ignore_suffix,
#     298     version_id=version_id,
#     299     ignore_empty=ignore_empty,
#     300     use_threads=use_threads,
#     301     s3_client=s3_client,
#     302     s3_additional_kwargs=s3_additional_kwargs,
#     303     chunksize=chunksize,
#     304     dataset=dataset,
#     305     partition_filter=partition_filter,
#     306     last_modified_begin=last_modified_begin,
#     307     last_modified_end=last_modified_end,
#     308     ignore_index=ignore_index,
#     309     ray_args=ray_args,
#     310     **pandas_kwargs,
#     311 )
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/s3/_read_text.py:93, in _read_text_format(read_format, path, path_suffix, path_ignore_suffix, ignore_empty, use_threads, last_modified_begin, last_modified_end, s3_client, s3_additional_kwargs, chunksize, dataset, partition_filter, ignore_index, ray_args, version_id, **pandas_kwargs)
#      91 if "iterator" in pandas_kwargs:
#      92     raise exceptions.InvalidArgument("Please, use the chunksize argument instead of iterator.")
# ---> 93 paths: List[str] = _path2list(
#      94     path=path,
#      95     s3_client=s3_client,
#      96     suffix=path_suffix,
#      97     ignore_suffix=_get_path_ignore_suffix(path_ignore_suffix=path_ignore_suffix),
#      98     ignore_empty=ignore_empty,
#      99     last_modified_begin=last_modified_begin,
#     100     last_modified_end=last_modified_end,
#     101     s3_additional_kwargs=s3_additional_kwargs,
#     102 )
#     104 path_root: Optional[str] = _get_path_root(path=path, dataset=dataset)
#     105 if path_root is not None:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/s3/_list.py:35, in _path2list(path, s3_client, s3_additional_kwargs, last_modified_begin, last_modified_end, suffix, ignore_suffix, ignore_empty)
#      33 _ignore_suffix: Optional[List[str]] = [ignore_suffix] if isinstance(ignore_suffix, str) else ignore_suffix
#      34 if isinstance(path, str):  # prefix
# ---> 35     paths: List[str] = [
#      36         path
#      37         for paths in _list_objects(
#      38             path=path,
#      39             s3_client=s3_client,
#      40             suffix=_suffix,
#      41             ignore_suffix=_ignore_suffix,
#      42             last_modified_begin=last_modified_begin,
#      43             last_modified_end=last_modified_end,
#      44             ignore_empty=ignore_empty,
#      45             s3_additional_kwargs=s3_additional_kwargs,
#      46         )
#      47         for path in paths
#      48     ]
#      49     _logger.debug("Listed %s paths", len(paths))
#      50 elif isinstance(path, list):
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/s3/_list.py:35, in <listcomp>(.0)
#      33 _ignore_suffix: Optional[List[str]] = [ignore_suffix] if isinstance(ignore_suffix, str) else ignore_suffix
#      34 if isinstance(path, str):  # prefix
# ---> 35     paths: List[str] = [
#      36         path
#      37         for paths in _list_objects(
#      38             path=path,
#      39             s3_client=s3_client,
#      40             suffix=_suffix,
#      41             ignore_suffix=_ignore_suffix,
#      42             last_modified_begin=last_modified_begin,
#      43             last_modified_end=last_modified_end,
#      44             ignore_empty=ignore_empty,
#      45             s3_additional_kwargs=s3_additional_kwargs,
#      46         )
#      47         for path in paths
#      48     ]
#      49     _logger.debug("Listed %s paths", len(paths))
#      50 elif isinstance(path, list):
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/awswrangler/s3/_list.py:146, in _list_objects_paginate(bucket, pattern, prefix, s3_client, delimiter, s3_additional_kwargs, suffix, ignore_suffix, last_modified_begin, last_modified_end, ignore_empty)
#     143 response_iterator = paginator.paginate(**args)
#     144 paths: List[str] = []
# --> 146 for page in response_iterator:  # pylint: disable=too-many-nested-blocks
#     147     if delimiter is None:
#     148         contents = page.get("Contents")
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/paginate.py:269, in PageIterator.__iter__(self)
#     267 self._inject_starting_params(current_kwargs)
#     268 while True:
# --> 269     response = self._make_request(current_kwargs)
#     270     parsed = self._extract_parsed_response(response)
#     271     if first_request:
#     272         # The first request is handled differently.  We could
#     273         # possibly have a resume/starting token that tells us where
#     274         # to index into the retrieved page.
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/paginate.py:357, in PageIterator._make_request(self, current_kwargs)
#     356 def _make_request(self, current_kwargs):
# --> 357     return self._method(**current_kwargs)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/client.py:963, in BaseClient._make_api_call(self, operation_name, api_params)
#     959     maybe_compress_request(
#     960         self.meta.config, request_dict, operation_model
#     961     )
#     962     apply_request_checksum(request_dict)
# --> 963     http, parsed_response = self._make_request(
#     964         operation_model, request_dict, request_context
#     965     )
#     967 self.meta.events.emit(
#     968     'after-call.{service_id}.{operation_name}'.format(
#     969         service_id=service_id, operation_name=operation_name
#    (...)
#     974     context=request_context,
#     975 )
#     977 if http.status_code >= 300:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/client.py:986, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#     984 def _make_request(self, operation_model, request_dict, request_context):
#     985     try:
# --> 986         return self._endpoint.make_request(operation_model, request_dict)
#     987     except Exception as e:
#     988         self.meta.events.emit(
#     989             'after-call-error.{service_id}.{operation_name}'.format(
#     990                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#     994             context=request_context,
#     995         )
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/endpoint.py:198, in Endpoint._send_request(self, request_dict, operation_model)
#     196 context = request_dict['context']
#     197 self._update_retries_context(context, attempts)
# --> 198 request = self.create_request(request_dict, operation_model)
#     199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/endpoint.py:134, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = 'request-created.{service_id}.{op_name}'.format(
#     132         service_id=service_id, op_name=operation_model.name
#     133     )
# --> 134     self._event_emitter.emit(
#     135         event_name,
#     136         request=request,
#     137         operation_name=operation_model.name,
#     138     )
#     139 prepared_request = self.prepare_request(request)
#     140 return prepared_request
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/signers.py:105, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     100 def handler(self, operation_name=None, request=None, **kwargs):
#     101     # This is typically hooked up to the "request-created" event
#     102     # from a client's event emitter.  When a new request is created
#     103     # this method is invoked to sign the request.
#     104     # Don't call this method directly.
# --> 105     return self.sign(operation_name, request)
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/signers.py:180, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     178     kwargs['signing_name'] = signing_context['signing_name']
#     179 try:
# --> 180     auth = self.get_auth_instance(**kwargs)
#     181 except UnknownSignatureVersionError as e:
#     182     if signing_type != 'standard':
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/signers.py:284, in RequestSigner.get_auth_instance(self, signing_name, region_name, signature_version, **kwargs)
#     282 frozen_credentials = None
#     283 if self._credentials is not None:
# --> 284     frozen_credentials = self._credentials.get_frozen_credentials()
#     285 kwargs['credentials'] = frozen_credentials
#     286 if cls.REQUIRES_REGION:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:611, in RefreshableCredentials.get_frozen_credentials(self)
#     577 def get_frozen_credentials(self):
#     578     """Return immutable credentials.
#     579
#     580     The ``access_key``, ``secret_key``, and ``token`` properties
#    (...)
#     609
#     610     """
# --> 611     self._refresh()
#     612     return self._frozen_credentials
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:499, in RefreshableCredentials._refresh(self)
#     495         return
#     496     is_mandatory_refresh = self.refresh_needed(
#     497         self._mandatory_refresh_timeout
#     498     )
# --> 499     self._protected_refresh(is_mandatory=is_mandatory_refresh)
#     500     return
#     501 finally:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:515, in RefreshableCredentials._protected_refresh(self, is_mandatory)
#     511 def _protected_refresh(self, is_mandatory):
#     512     # precondition: this method should only be called if you've acquired
#     513     # the self._refresh_lock.
#     514     try:
# --> 515         metadata = self._refresh_using()
#     516     except Exception:
#     517         period_name = 'mandatory' if is_mandatory else 'advisory'
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:662, in CachedCredentialFetcher.fetch_credentials(self)
#     661 def fetch_credentials(self):
# --> 662     return self._get_cached_credentials()
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:672, in CachedCredentialFetcher._get_cached_credentials(self)
#     670 response = self._load_from_cache()
#     671 if response is None:
# --> 672     response = self._get_credentials()
#     673     self._write_to_cache(response)
#     674 else:
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/credentials.py:2115, in SSOCredentialFetcher._get_credentials(self)
#    2113 if self._token_provider:
#    2114     initial_token_data = self._token_provider.load_token()
# -> 2115     token = initial_token_data.get_frozen_token().token
#    2116 else:
#    2117     token = self._token_loader(self._start_url)['accessToken']
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/tokens.py:82, in DeferredRefreshableToken.get_frozen_token(self)
#      81 def get_frozen_token(self):
# ---> 82     self._refresh()
#      83     return self._frozen_token
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/tokens.py:95, in DeferredRefreshableToken._refresh(self)
#      93 if self._refresh_lock.acquire(block_for_refresh):
#      94     try:
# ---> 95         self._protected_refresh()
#      96     finally:
#      97         self._refresh_lock.release()
#
# File ~/.local/share/virtualenvs/SumarAI-GSxOyqCd/lib/python3.10/site-packages/botocore/tokens.py:122, in DeferredRefreshableToken._protected_refresh(self)
#     118         raise
#     120 if self._is_expired():
#     121     # Fresh credentials should never be expired
# --> 122     raise TokenRetrievalError(
#     123         provider=self.method,
#     124         error_msg="Token has expired and refresh failed",
#     125     )
#
# TokenRetrievalError: Error when retrieving token from sso: Token has expired and refresh failed

# %%
# get collection from server
model = INSTRUCTOR('hkunlp/instructor-large')
server_ip = os.getenv('CHROMA_SERVER_IP')
client = chromadb.HttpClient(host=server_ip, port=8000)
collection = client.get_collection(name="transcripts-2", embedding_function=model)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# Try querying the database
query_texts=[['Represent the topic for retrieving relevant Podcast transcripts: ',"Economy"]]
query_embedding = model.encode(query_texts).tolist()
collection.query(
    query_embeddings=query_embedding,
    n_results=3
)
#client.list_collections()
collection.count()
# Out:
# 3955

# %%
transcripts_df[['episode_description']].to_dict(orient='records')

# %%
read_and_preprocess_transcripts(filepath)
# Out:
#                                              transcript  \
# 0     Welcome back to GRE vocab.  Before we continue...
# 1     Welcome back to another episode of a GRE vocab...
# 2     Welcome back to the GRE vocab podcast. We use ...
# 3     Welcome back to episode 5 of GRE vocab today t...
# 4     Welcome back to GRE vocab today are five words...
# ...                                                 ...
# 4020  ere's no harm in being personal personal reall...
# 4021  Hello, my name is Quinton Pastrana. Welcome to...
# 4022  Over the span of 12 months to larger-than-life...
# 4023  My name is Quinton Pastrana. Welcome to anothe...
# 4024  Hi, everyone. This is life sentences. My name ...
#
#                              show                 episode  \
# 0     show_00iaP2GhJUWHAovx41BN5N  2VVBXyGRGd2cydXPxHJme6
# 1     show_00iaP2GhJUWHAovx41BN5N  3jIQUvPSaCcMOpJfx5AB1w
# 2     show_00iaP2GhJUWHAovx41BN5N  3iRJkm19fnZkdwW7nTX5Yb
# 3     show_00iaP2GhJUWHAovx41BN5N  3vdykhEg3lYhfXEVIIB8GH
# 4     show_00iaP2GhJUWHAovx41BN5N  4Xsex7XPthez6srVIdv4vU
# ...                           ...                     ...
# 4020  show_09UZ3QZQGagWfnPMgZYccR  1H2m1fhwmVpeEf0N4YZVgB
# 4021  show_09NfbvW32HL0dKd4gxxBCk  4ch15nYQdO4kNW2v4Yy4Wz
# 4022  show_09NfbvW32HL0dKd4gxxBCk  1YGjk9nbFi4onBQhad0hYv
# 4023  show_09NfbvW32HL0dKd4gxxBCk  3fzo9XOqqNlfp10lIcFJGm
# 4024  show_09NfbvW32HL0dKd4gxxBCk  24icURlwEmszq89rzsyUlH
#
#                                  show_uri         show_name  \
# 0     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 1     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 2     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 3     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 4     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# ...                                   ...               ...
# 4020  spotify:show:09UZ3QZQGagWfnPMgZYccR  The Food Podcast
# 4021  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4022  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4023  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4024  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
#
#                                        show_description         publisher  \
# 0     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 1     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 2     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 3     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 4     We use publicly recommended vocab words that m...      GRE Vocab Yo
# ...                                                 ...               ...
# 4020  The Food Podcast is a show where personal stor...  The Food Podcast
# 4021  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4022  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4023  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4024  Words to live by and die for. Life Sentences p...       PumaPodcast
#
#        language                                  rss_link  \
# 0     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 1     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 2     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 3     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 4     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# ...         ...                                       ...
# 4020     ['en']   https://anchor.fm/s/4887ad0/podcast/rss
# 4021  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4022  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4023  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4024  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
#
#                                  episode_uri  \
# 0     spotify:episode:2VVBXyGRGd2cydXPxHJme6
# 1     spotify:episode:3jIQUvPSaCcMOpJfx5AB1w
# 2     spotify:episode:3iRJkm19fnZkdwW7nTX5Yb
# 3     spotify:episode:3vdykhEg3lYhfXEVIIB8GH
# 4     spotify:episode:4Xsex7XPthez6srVIdv4vU
# ...                                      ...
# 4020  spotify:episode:1H2m1fhwmVpeEf0N4YZVgB
# 4021  spotify:episode:4ch15nYQdO4kNW2v4Yy4Wz
# 4022  spotify:episode:1YGjk9nbFi4onBQhad0hYv
# 4023  spotify:episode:3fzo9XOqqNlfp10lIcFJGm
# 4024  spotify:episode:24icURlwEmszq89rzsyUlH
#
#                                            episode_name  \
# 0     Fatuous • Apocryphal • Acridity • Trenchancy •...
# 1     Phlegmatic • laconic • probity • proclivity • ...
# 2     Punctilious • Vociferous • Waggish • Panegyric...
# 3     Halcyon • hedonism • iconoclast • impunity • i...
# 4     Prodigal • Rancorous • Salubrious • Querulous ...
# ...                                                 ...
# 4020  THE FOOD PODCAST 029 -Making friends and feedi...
# 4021                         Episode 1: Mi Ultimo Adiós
# 4022  Episode 4: A tribute to Twink Macaraig and Mar...
# 4023                          Episode 2: Year End Poems
# 4024                    Episode 3: Riverrun, through it
#
#                                     episode_description   duration  \
# 0     Trump. Genius or idiot? Brilliant or buffoon? ...   2.809233
