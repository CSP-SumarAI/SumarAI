# %%
from InstructorEmbedding import INSTRUCTOR

import os
import pandas as pd
import pathlib
import chromadb
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from matplotlib import pyplot as plt

os.environ["OPENAI_API_KEY"] = ""

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../src/data/'))
from s3_utils import read_from_s3, write_to_s3
from chromadb.config import Settings
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
def preprocess_transcripts(transcripts_df):
    """ 
    Function that does preprocessing steps:
    - Split transcripts into chunks of 20000 characters
    - Explode to new rows
    - Remove transcripts with less than 1000 characters
    """
    transcripts_df['transcript'] = transcripts_df['transcript'].apply(lambda x: [x[i:i+20000] for i in range(0, len(x), 20000)])
    transcripts_df = transcripts_df.explode('transcript')
    transcripts_df['transcript_length'] = transcripts_df['transcript'].apply(lambda x: len(x))
    transcripts_df = transcripts_df[transcripts_df['transcript_length'] > 1000].reset_index(drop=True)
    return transcripts_df

# %%
# prepare texts with instructions
instruction = "Represent the Podcast transcript for retrieval: "

# read transcript data
filename = 'podcasts-transcripts-0to2-35.csv'

transcripts_df = read_from_s3(filename, filetype=None)
transcripts_df = preprocess_transcripts(transcripts_df)
transcripts_df = transcripts_df.head(100)

# Create list of instruction - transcript pairs (100 first episodes)
# transcripts_df  = transcripts_df.head(100)
texts_with_instructions = []
for index, row in transcripts_df.iterrows():
    texts_with_instructions.append([instruction, row["transcript"]])

# calculate embeddings (100 first episodes took about 6 min)
model = INSTRUCTOR('hkunlp/instructor-large')
customized_embeddings = model.encode(texts_with_instructions, show_progress_bar=True, batch_size=16)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512
# Batches: 100%|██████████| 7/7 [06:14<00:00, 53.46s/it]

# %%
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
persist_directory = 'test-db'

# format data that if can be put to the chroma collection
embeddings = customized_embeddings.tolist()
documents = transcripts_df["transcript"].tolist()
ids = transcripts_df.index.astype(str).to_list()
metadata = transcripts_df[['episode_description', 'episode_name']].to_dict(orient='records')

#loading into chroma
#client = chromadb.PersistentClient(path=persist_directory)
model = INSTRUCTOR('hkunlp/instructor-large')
server_ip = os.getenv('CHROMA_SERVER_IP')
client = chromadb.HttpClient(host=server_ip, port=8000)
collection = client.get_collection(name="transcripts", embedding_function=model)


# create the collection and add documents
try:
    client.delete_collection("transcripts")
except Exception as e:
    pass
collection = client.create_collection("transcripts", embedding_function=model)
collection.add(
    embeddings=embeddings,
    documents=documents,
    metadatas=metadata,
    ids=ids,
)

# %%
import boto3
import pandas as pd
#my_session = boto3.Session(region_name='eu-central-1', profile_name='my-admin-profile')
client = boto3.client('s3')
files = client.list_objects(Bucket='sumar-ai')['Contents']
filenames = [f['Key'] for f in files]
processed_files = pd.DataFrame(filenames[:5], columns=['processed_files'])

write_to_s3(processed_files, 'processed_files', 'metadata')

# %%
processed_files_df = read_from_s3('processed_files', 'metadata')
processed_files_list = list(processed_files_df.processed_files)
# Out:
# ['transcripts/podcasts-transcripts-0to2-1.csv',
#  'transcripts/podcasts-transcripts-0to2-10.csv',
#  'transcripts/podcasts-transcripts-0to2-11.csv',
#  'transcripts/podcasts-transcripts-0to2-12.csv',
#  'transcripts/podcasts-transcripts-0to2-13.csv']

# %%
# get collection from server
model = INSTRUCTOR('hkunlp/instructor-large')
server_ip = os.getenv('CHROMA_SERVER_IP')
client = chromadb.HttpClient(host=server_ip, port=8000)
collection = client.get_collection(name="transcripts", embedding_function=model)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
# Try querying the database
query_texts=[['Represent the topic for retrieving relevant Podcast transcripts: ',"Sports"]]
query_embedding = model.encode(query_texts).tolist()
collection.query(
    query_embeddings=query_embedding,
    n_results=5
)
# Out:
# {'ids': [['220', '221', '1297', '206', '2187']],
#  'distances': [[0.3547995090484619,
#    0.36153286695480347,
#    0.38233038783073425,
#    0.3846590220928192,
#    0.3865782916545868]],
#  'embeddings': None,
#  'metadatas': [[{'episode_description': 'After two NBA-centric eps, Coop & Cal invite their first guest onto the show to help them break the hockey barrier. Joe Milo, a former college hockey player, clocks in to talk Stanley Cup finals, the physical repercussions of pro sports, and how Wayne Gretzky stacks up to other sports greats. There is also a surprisingly complete conversation about whether or not college athletes should be paid.\xa0 ',
#     'episode_name': '003: Six Pairs of Garage Doors'},
#    {'episode_description': 'After two NBA-centric eps, Coop & Cal invite their first guest onto the show to help them break the hockey barrier. Joe Milo, a former college hockey player, clocks in to talk Stanley Cup finals, the physical repercussions of pro sports, and how Wayne Gretzky stacks up to other sports greats. There is also a surprisingly complete conversation about whether or not college athletes should be paid.\xa0 ',
#     'episode_name': '003: Six Pairs of Garage Doors'},
#    {'episode_description': '         Matt and Greg are back with another deep dive into the college and pro football slate. They come together with a MAX college football bet, look at college favorites in the first half, discuss if Daniel Jones is real, and a MAX NFL parlay you do not want to miss.        ',
#     'episode_name': 'Showtime Goes Undercover With Greg: Ready to Cash a Consensus Max College Football Play?'},
#    {'episode_description': "On episode 50, we discuss the greatness of Kobe Bryant after his tragic passing, we preview the Super Bowl, BOTW, and talk Netflix's hit docu-series, Cheer!  ---   Send in a voice message: https://anchor.fm/bigswing/message",
#     'episode_name': 'Remembering Kobe, Super Bowl Preview, BOTW, Cheer'},
#    {'episode_description': 'Here we go!!! The start of this podcast, Kyle and I catch up back at Kent State University talk about being back and what this semester is gonna bring. ',
#     'episode_name': 'The Pre-Game Episode 1 '}]],
#  'documents': [["Welcome to span Sports Network with cooping Cal the premise of the show is very simple. I know almost nothing and Cal knows very little but that doesn't stop us from acting like we got the Sports World all figured out usually this leads to us making lots of mistakes. But this week we had our first guest Joe Milo and he talked so fucking much. We even have a chance to mess anything up. Don't worry. Everything's going to be fine. We can like line them all up. You dance like toughen the honking. Thank you. Got one two, three. What's up spins Sports Network ins even come up with a name for our fans yet. I think you have to have sporks three three digits worth of fans before you can nickname them. We're here with our first ever guest. Give a warm. Welcome to Joe Joe. What Joe? No speed you could listen all six if we I did I did even though it seems the second one first. So I just finished it and the first one I just finished that in the car ride as well. Thank you so much. Joe has a fresh. I'm a farmer. Yeah former hockey player played low-level D3 hockey. No big deal should have played a really crappy D1 school, but I chose education good for you because I knew I wasn't  Making it no dad and I was like a similar story. Yeah, I was just going to say I knew we would have something to talk about because I played hockey but it sounds like even more tangibly. I went to Columbia to play a shitty D1 basketball and made mistake you didn't make because I could have started at three or four d three schools as a sophomore and I was so public school that I wanted to talk shit and tell everyone I played D1.  I quit after eight games. Yeah, because no I quit senior year though because my coach I heard my hurt
# 4     show_00iaP2GhJUWHAovx41BN5N  4Xsex7XPthez6srVIdv4vU
# ...                           ...                     ...
# 4020  show_09UZ3QZQGagWfnPMgZYccR  1H2m1fhwmVpeEf0N4YZVgB
# 4021  show_09NfbvW32HL0dKd4gxxBCk  4ch15nYQdO4kNW2v4Yy4Wz
# 4022  show_09NfbvW32HL0dKd4gxxBCk  1YGjk9nbFi4onBQhad0hYv
# 4023  show_09NfbvW32HL0dKd4gxxBCk  3fzo9XOqqNlfp10lIcFJGm
# 4024  show_09NfbvW32HL0dKd4gxxBCk  24icURlwEmszq89rzsyUlH
#
#                                  show_uri         show_name  \
# 0     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 1     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 2     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 3     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# 4     spotify:show:00iaP2GhJUWHAovx41BN5N         GRE Vocab
# ...                                   ...               ...
# 4020  spotify:show:09UZ3QZQGagWfnPMgZYccR  The Food Podcast
# 4021  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4022  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4023  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
# 4024  spotify:show:09NfbvW32HL0dKd4gxxBCk    Life Sentences
#
#                                        show_description         publisher  \
# 0     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 1     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 2     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 3     We use publicly recommended vocab words that m...      GRE Vocab Yo
# 4     We use publicly recommended vocab words that m...      GRE Vocab Yo
# ...                                                 ...               ...
# 4020  The Food Podcast is a show where personal stor...  The Food Podcast
# 4021  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4022  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4023  Words to live by and die for. Life Sentences p...       PumaPodcast
# 4024  Words to live by and die for. Life Sentences p...       PumaPodcast
#
#        language                                  rss_link  \
# 0     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 1     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 2     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 3     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# 4     ['en-US']   https://anchor.fm/s/9b4ae84/podcast/rss
# ...         ...                                       ...
# 4020     ['en']   https://anchor.fm/s/4887ad0/podcast/rss
# 4021  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4022  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4023  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
# 4024  ['en-PH']  https://anchor.fm/s/11afbcc8/podcast/rss
#
#                                  episode_uri  \
# 0     spotify:episode:2VVBXyGRGd2cydXPxHJme6
# 1     spotify:episode:3jIQUvPSaCcMOpJfx5AB1w
# 2     spotify:episode:3iRJkm19fnZkdwW7nTX5Yb
# 3     spotify:episode:3vdykhEg3lYhfXEVIIB8GH
# 4     spotify:episode:4Xsex7XPthez6srVIdv4vU
# ...                                      ...
# 4020  spotify:episode:1H2m1fhwmVpeEf0N4YZVgB
# 4021  spotify:episode:4ch15nYQdO4kNW2v4Yy4Wz
# 4022  spotify:episode:1YGjk9nbFi4onBQhad0hYv
# 4023  spotify:episode:3fzo9XOqqNlfp10lIcFJGm
# 4024  spotify:episode:24icURlwEmszq89rzsyUlH
#
#                                            episode_name  \
# 0     Fatuous • Apocryphal • Acridity • Trenchancy •...
# 1     Phlegmatic • laconic • probity • proclivity • ...
# 2     Punctilious • Vociferous • Waggish • Panegyric...
# 3     Halcyon • hedonism • iconoclast • impunity • i...
# 4     Prodigal • Rancorous • Salubrious • Querulous ...
# ...                                                 ...
# 4020  THE FOOD PODCAST 029 -Making friends and feedi...
# 4021                         Episode 1: Mi Ultimo Adiós
# 4022  Episode 4: A tribute to Twink Macaraig and Mar...
# 4023                          Episode 2: Year End Poems
# 4024                    Episode 3: Riverrun, through it
#
#                                     episode_description   duration  \
# 0     Trump. Genius or idiot? Brilliant or buffoon? ...   2.809233
# 1     Who win and be Trumps challenger? NBA vs China...   3.593667
# 2     Astros are freaking busted! Messed up...messed...   3.347933
# 3     We’re talking Lebron and MJ. Messi and Barcelo...   4.140900
# 4     NASA is going to the moon...AGAIN!? And they w...   4.011250
# ...                                                 ...        ...
# 4020  On today’s episode, Hetty McKinnon and I share...  29.926400
# 4021  Mi Ultimo Adiós: Rizal's farewell revisited an...  12.916483
# 4022  A tribute to veteran journalist Twink Macaraig...   8.090550
# 4023  New Year's resolutions: a pair of spiritual an...   7.135883
# 4024  Riverrun, through it: an exploration and exclu...  14.113083
#
#              show_filename_prefix episode_filename_prefix  transcript_length
# 0     show_00iaP2GhJUWHAovx41BN5N  2VVBXyGRGd2cydXPxHJme6               1951
# 1     show_00iaP2GhJUWHAovx41BN5N  3jIQUvPSaCcMOpJfx5AB1w               2480
# 2     show_00iaP2GhJUWHAovx41BN5N  3iRJkm19fnZkdwW7nTX5Yb               2144
# 3     show_00iaP2GhJUWHAovx41BN5N  3vdykhEg3lYhfXEVIIB8GH               3362
# 4     show_00iaP2GhJUWHAovx41BN5N  4Xsex7XPthez6srVIdv4vU               2995
# ...                           ...                     ...                ...
# 4020  show_09UZ3QZQGagWfnPMgZYccR  1H2m1fhwmVpeEf0N4YZVgB               5583
# 4021  show_09NfbvW32HL0dKd4gxxBCk  4ch15nYQdO4kNW2v4Yy4Wz               8111
# 4022  show_09NfbvW32HL0dKd4gxxBCk  1YGjk9nbFi4onBQhad0hYv               4765
# 4023  show_09NfbvW32HL0dKd4gxxBCk  3fzo9XOqqNlfp10lIcFJGm               4926
# 4024  show_09NfbvW32HL0dKd4gxxBCk  24icURlwEmszq89rzsyUlH              11182
#
# [4025 rows x 16 columns]

# %%
print(transcripts_df.loc[0,'transcript'])
# Out:
# Welcome back to GRE vocab.  Before we continue. We just want to give a quick shout out to the people who make this podcast possible. Anchor anchor is everything you need to make a podcast in one place. They distribute your podcast for you. They have tools that allow you to record and edit everything right from your phone or computer. It's free the even allow you to put ads in your your podcast. It's pretty awesome. Go check it out download the free anchor app or go to Anchored off dot f m-- to get started. Okay, let's get back to the show.  Today's words are fatuous, silly and pointless apocryphal.  Of doubtful authenticity, although widely circulated as being true usually in regards to a story or statement a credit e having an acrid smell accurate is having an irritant Lee Strong and unpleasant taste or smell angry bitter.  Trench in see in size of - keenness and forcefulness of thought or expression or intellect euphony the quality of being pleasing to the ear, especially through a harmonious combination of words.  Trump trump Trump trump no matter what you think of him. You got to admit. He's very entertaining especially when it comes to his tweets.  A lot of his tweets are completely fascists. Remember the the whole kafei tweet where he tweeted a word that said Kofi. I like 2:00 in the morning unbelievable. Basically all of his tweets are trenchant. He's very bold once everyone to listen every once in a while though. He'll have a rather euphonious comment. I assume those pleasing tweets are in by his professional speech writers right now is impeachment trial is  Underway, some say is conversation with Ukrainian president clearly frames it but others say it that is apocryphal. We'll just have to see what happens.  That's all for GRE vocab. We wish you guys the best of luck if you're taking the test this week.  Also, if you wouldn't mind leaving us a review the be much appreciated. Thanks so much. See you next time.
